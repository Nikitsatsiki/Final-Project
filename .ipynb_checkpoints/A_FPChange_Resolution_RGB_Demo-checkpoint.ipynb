# %% [markdown]
# # Change Resolution & RGB Demo
# #### In this notebook ......
# ##### TBD

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
sea = Image.open("data/resolution/DSC05511.jpg");

# %%
sea.size #scale new image in the same order (e.g. 4.8 * 2.7)
         #the size must be integer, so I go with 5 * 3 and multiples
# Out:
# (4896, 2752)

# %%
fig,ax=plt.subplots(figsize=(5, 3))
ax.imshow(sea);

# %%
sea_reduced = sea.resize((15, 9), Image.ANTIALIAS) #ANTIALIAS: a high-quality downsampling filter
np.asarray(sea_reduced)
# Out:
# array([[[108, 140, 193],
#         [113, 145, 196],
#         [119, 152, 200],
#         [124, 157, 205],
#         [128, 160, 207],
#         [129, 162, 208],
#         [130, 162, 208],
#         [129, 162, 208],
#         [127, 159, 206],
#         [123, 156, 205],
#         [118, 152, 202],
#         [113, 146, 199],
#         [106, 140, 193],
#         [100, 134, 188],
#         [ 93, 128, 183]],
#
#        [[115, 148, 199],
#         [119, 153, 201],
#         [125, 159, 207],
#         [129, 163, 210],
#         [132, 165, 212],
#         [133, 166, 212],
#         [134, 167, 212],
#         [133, 166, 212],
#         [130, 164, 210],
#         [125, 160, 208],
#         [121, 156, 207],
#         [116, 152, 204],
#         [111, 147, 200],
#         [105, 141, 194],
#         [101, 136, 191]],
#
#        [[125, 158, 204],
#         [129, 163, 208],
#         [134, 168, 213],
#         [137, 171, 215],
#         [139, 173, 216],
#         [140, 174, 217],
#         [140, 174, 217],
#         [139, 173, 216],
#         [136, 171, 215],
#         [133, 168, 213],
#         [128, 165, 212],
#         [124, 161, 210],
#         [120, 157, 207],
#         [115, 152, 202],
#         [111, 147, 198]],
#
#        [[142, 172, 208],
#         [146, 177, 213],
#         [151, 182, 218],
#         [153, 184, 220],
#         [154, 186, 221],
#         [155, 186, 222],
#         [153, 186, 221],
#         [152, 185, 221],
#         [149, 183, 220],
#         [146, 180, 219],
#         [141, 177, 217],
#         [137, 173, 215],
#         [132, 169, 212],
#         [127, 164, 208],
#         [122, 159, 203]],
#
#        [[144, 166, 194],
#         [151, 174, 201],
#         [159, 182, 207],
#         [165, 186, 211],
#         [169, 190, 214],
#         [171, 193, 216],
#         [172, 193, 216],
#         [169, 191, 214],
#         [164, 188, 213],
#         [162, 186, 212],
#         [160, 185, 212],
#         [155, 182, 210],
#         [152, 179, 209],
#         [149, 176, 206],
#         [144, 171, 201]],
#
#        [[ 57,  85, 130],
#         [ 62,  90, 134],
#         [ 72,  99, 141],
#         [ 83, 110, 150],
#         [ 90, 116, 153],
#         [ 91, 116, 153],
#         [ 94, 120, 155],
#         [ 92, 118, 154],
#         [ 86, 113, 151],
#         [ 83, 110, 150],
#         [ 77, 106, 148],
#         [ 72, 101, 145],
#         [ 69,  98, 142],
#         [ 67,  94, 139],
#         [ 64,  90, 134]],
#
#        [[ 45,  73, 122],
#         [ 51,  79, 125],
#         [ 56,  84, 128],
#         [ 54,  82, 128],
#         [ 54,  83, 128],
#         [ 53,  82, 128],
#         [ 57,  87, 131],
#         [ 60,  90, 134],
#         [ 58,  88, 132],
#         [ 51,  80, 126],
#         [ 46,  78, 126],
#         [ 45,  76, 126],
#         [ 38,  70, 120],
#         [ 32,  61, 110],
#         [ 26,  52,  99]],
#
#        [[ 36,  50,  79],
#         [ 45,  61,  91],
#         [ 48,  68, 105],
#         [ 51,  75, 117],
#         [ 49,  74, 119],
#         [ 48,  75, 119],
#         [ 41,  67, 112],
#         [ 44,  69, 112],
#         [ 47,  71, 113],
#         [ 40,  65, 109],
#         [ 40,  65, 109],
#         [ 41,  69, 114],
#         [ 41,  69, 114],
#         [ 42,  71, 117],
#         [ 39,  67, 115]],
#
#        [[ 20,  32,  61],
#         [ 22,  31,  53],
#         [ 32,  41,  62],
#         [ 44,  53,  72],
#         [ 49,  58,  78],
#         [ 63,  77, 104],
#         [ 60,  79, 115],
#         [ 43,  63, 101],
#         [ 47,  64,  98],
#         [ 26,  44,  81],
#         [ 24,  42,  80],
#         [ 22,  40,  78],
#         [ 18,  34,  69],
#         [ 21,  39,  76],
#         [ 24,  43,  83]]], dtype=uint8)

# %%
fig, ax = plt.subplots(figsize=(30, 50))
plt.imshow(sea_reduced);

# %%
sea_reduced.save('sea_reduced.jpg')

# %%
sea_blue = Image.open('sea_reduced.jpg')
sea_blue.putpixel((0,0),(255,0,0))
sea_blue.putpixel((0,1),(0,255,0))
sea_blue.putpixel((0,2),(0,0,255))
sea_blue.putpixel((0,3),(0,0,0))
sea_blue.putpixel((0,4),(255,255,255))
sea_blue.putpixel((0,5),(85,85,85))
sea_blue.putpixel((0,6),(85,0,0))
sea_blue.putpixel((0,7),(0,85,0))
sea_blue.putpixel((0,8),(0,0,85))
a=sea_blue.getpixel((4,4))#,(50,0,200))
plt.imshow(sea_blue);
a
# Out:
# (161, 189, 228)
