# %% [markdown]
# # Visualizing Discrete Wavalet Transform

# %%
import numpy as np
import pandas as pd
import os
from PIL import Image
import pywt
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#img_name = 'DSC_7928' #very nice because of pfosten und boot
#img_name = 'DSC_7653' #very good briefkasten 4 kanten, but why it turns? is CR also better here?

# %%
data_img = np.asarray(Image.open(f"data/{img_name}.jpg"))
r = data_img[:,:,0]
g = data_img[:,:,1]
b = data_img[:,:,2]
    
coeff_r = pywt.dwt2(r, 'bior1.3')
coeff_g = pywt.dwt2(g, 'bior1.3')
coeff_b = pywt.dwt2(b, 'bior1.3')
    
LL_r, (LH_r, HL_r, HH_r) = coeff_r
LL_g, (LH_g, HL_g, HH_g) = coeff_g
LL_b, (LH_b, HL_b, HH_b) = coeff_b
    
    #LL, (LH, HL, HH) = coeffs2
titles = ['Approximation', ' Horizontal detail',
          'Vertical detail', 'Diagonal detail']
fig = plt.figure(figsize=(48, 12))
for i, a in enumerate([LL_r, LH_r, HL_r, HH_r]):
    ax = fig.add_subplot(1, 4, i + 1)
    ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
    ax.set_title(titles[i], fontsize=10)
    ax.set_xticks([])
    ax.set_yticks([])

#fig.tight_layout()
#plt.show()  
  
    
    
# LL Approx of it from den 3 oder so

# R G B mit stack
# oder stack them together

# %%
#1st add or show individuall or stack ok  interpret as BW or make at lest with stack to real r g b 
#function Real RGB

# %%
LL, (LH, HL, HH) = coeffs2
fig = plt.figure(figsize=(12, 3))
for i, a in enumerate([LL, LH, HL, HH]):
    ax = fig.add_subplot(1, 4, i + 1)
    ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
    ax.set_title(titles[i], fontsize=10)
    ax.set_xticks([])
    ax.set_yticks([])

fig.tight_layout()
plt.show()

# %%
#einzeln oder rgb stacken?!
#contribute

# %%
plt.imshow(HH,cmap='Greys',interpolation='nearest');
