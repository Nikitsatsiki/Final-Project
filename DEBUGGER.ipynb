# %%
import DWT #sparse nicht sparse nachdenken
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
my_dwt=DWT.create(DWT.get_array('DSC00315'), 'bior1.3')

# %%
#my_dwt.plot_DWT('r') #self muss ich nie übergeben(self ist ein Klassenobject) und plot_DWT eine klassenfucntion
#Problem: Wir wollen 3 Sparse matrizen plotten, 
#das in der funktionändern

# %%
#erg=my_dwt.invert()

# %%
#plt.imshow(erg.astype(int));

# %%
new_dwt=my_dwt.sparsify_abs(0.01)

# %%
new_dwt.plot_DWT('r') #grauen auf schwarz (0)

# %%
approx=new_dwt.invert()

# %%
plt.imshow(approx.astype(int));
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
my_dwt.storage_size()
# Out:
# 52527657

# %%
new_dwt.storage_size()
# Out:
# 52527657

# %%
img_str='DSC00315'

# %%
data=np.asarray(Image.open(f"data/{img_str}.jpg"))

# %%
data.shape[0]*data.shape[1]*3
# Out:
# 40421376

# %%
#storage size sinnvoller
#sparse matrizen raus
#noise
#präsi
#mehr debuggen
